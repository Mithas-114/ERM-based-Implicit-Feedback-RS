# %%
from utils.utils import plot, read_scores
import pandas as pd

# %%
task = 1
Data = {
    0: {
        "model_type" : 0,
        "scores" : {
            "" : {
                {k : score}
            }
        }
    }  
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       1 task = 1
#       2 Data = {
#       3     0: {
#       4         "model_type" : 0,
#       5         "scores" : {
#       6             "" : {
# ----> 7                 {k : score}
#       8             }
#       9         }
#      10     }
#      11 }
#
# NameError: name 'k' is not defined

# %%
a = pd.read_csv("TestRecord-非消融/power=0/model_type=0/mean.csv").iloc[:, 1:].rename(index={0:"NDCG", 1:"MAP", 2:"RECALL"})

# %%
{1:2}.items()
# Out:
# dict_items([(1, 2)])

# %%
dict(a.loc["NDCG"])
# Out:
# {'1': 0.0588110403397027,
#  '3': 0.1111857750242659,
#  '5': 0.1392443044881638,
#  '8': 0.168600075135242,
#  '10': 0.1832737237951051}

# %%
read_scores("TestRecord-非消融/power=0/model_type=0/mean.csv")
# Out:
# {'NDCG': {'1': 0.0588110403397027,
#   '3': 0.1111857750242659,
#   '5': 0.1392443044881638,
#   '8': 0.168600075135242,
#   '10': 0.1832737237951051},
#  'MAP': {'1': 0.0588110403397027,
#   '3': 0.0760910592120783,
#   '5': 0.0796866006133522,
#   '8': 0.0815636677884175,
#   '10': 0.0821217396607144},
#  'RECALL': {'1': 0.0588110403397027,
#   '3': 0.1501061571125265,
#   '5': 0.2182590233545647,
#   '8': 0.3057324840764331,
#   '10': 0.3554140127388535}}

# %%
import os
os.listdir("TestRecord")
# Out:
# ['power=0.5', 'power=0', 'power=1.5', 'power=1', 'power=2']

# %%
import re
re.findall(r'\d+', "power=222")
# Out:
# ['222']

# %%
Data = read_scores("TestRecord-非消融")

# %%
plot(1, Data)
